# %%
## 1. Job Market

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("job-market.csv")

# %%
df.head(3)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
#
#                Company                      Date               Location  \
# 0          Aldi Stores  2018-10-07T00:00:00.000Z                 Sydney
# 1          Aldi Stores  2018-10-07T00:00:00.000Z  Richmond & Hawkesbury
# 2  LB Creative Pty Ltd  2018-10-07T00:00:00.000Z               Brisbane
#
#                           Area              Classification  SubClassification  \
# 0  North West & Hills District  Retail & Consumer Products  Retail Assistants
# 1                          NaN  Retail & Consumer Products  Retail Assistants
# 2          CBD & Inner Suburbs  Retail & Consumer Products  Retail Assistants
#
#                                          Requirement FullDescription  \
# ...

# %%
pd.DataFrame(df.Company.value_counts())
# Out:
#                                 Company
# Jora Local                          764
# Design & Build                       86
# Programmed Skilled Workforce         67
# HOBAN Recruitment                    44
# Coles                                44
# ...                                 ...
# Bowls Australia                       1
# Courage Health & Fitness              1
# Echo Group Corporation Pty Ltd        1
# Zenith Pacific                        1
# Youthcare                             1
#
# [4326 rows x 1 columns]

# %%
Labels = [df.Company]
sizes = [df.Company.value_counts()]

fig, ax = plt.subplots()
ax.pie(sizes, Labels)
plt_title('No. of workers at Companies')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/h0/8_wby_212cs0h3_gmjklt61c0000gn/T/ipykernel_8401/1995634139.py in <module>
#       3
#       4 fig, ax = plt.subplots()
# ----> 5 ax.pie(sizes, Labels)
#       6 plt_title('No. of workers at Companies')
#       7
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
# ...

# %%
pd.DataFrame(df.Location.value_counts())
# Out:
#                                       Location
# Sydney                                    2784
# Melbourne                                 2481
# Brisbane                                  1119
# Perth                                      677
# Adelaide                                   390
# ...                                        ...
# Fleurieu Peninsula & Kangaroo Island         6
# Tumut, Snowy & Monaro                        4
# Somerset & Lockyer                           4
# Central & South East TAS                     3
# Coober Pedy & Outback SA                     1
#
# [65 rows x 1 columns]

# %%
pd.DataFrame(df.Classification.value_counts())
# Out:
#                                         Classification
# Hospitality & Tourism                             1585
# Trades & Services                                 1225
# Manufacturing, Transport & Logistics               990
# Retail & Consumer Products                         896
# Administration & Office Support                    746
# Healthcare & Medical                               622
# Information & Communication Technology             411
# Education & Training                               401
# Sales                                              389
# Accounting                                         378
# Call Centre & Customer Service                     342
# Construction                                       265
# Community Services & Development                   258
# Real Estate & Property                             228
# Government & Defence                               203
# Mining, Resources & Energy                         176
# ...

# %%
pd.DataFrame(df.Classification.value_counts(normalize=True))
# Out:
#                                         Classification
# Hospitality & Tourism                         0.156946
# Trades & Services                             0.121299
# Manufacturing, Transport & Logistics          0.098030
# Retail & Consumer Products                    0.088722
# Administration & Office Support               0.073869
# Healthcare & Medical                          0.061590
# Information & Communication Technology        0.040697
# Education & Training                          0.039707
# Sales                                         0.038519
# Accounting                                    0.037429
# Call Centre & Customer Service                0.033865
# Construction                                  0.026240
# Community Services & Development              0.025547
# Real Estate & Property                        0.022576
# Government & Defence                          0.020101
# Mining, Resources & Energy                    0.017427
# ...

# %%
byLocation = df.groupby("Location").Classification.value_counts(normalize=True)
byLocation
# Out:
# Location                        Classification
# ACT                             Retail & Consumer Products                0.142857
#                                 Hospitality & Tourism                     0.134454
#                                 Administration & Office Support           0.100840
#                                 Information & Communication Technology    0.100840
#                                 Trades & Services                         0.092437
#                                                                             ...
# Yorke Peninsula & Clare Valley  Community Services & Development          0.363636
#                                 Manufacturing, Transport & Logistics      0.272727
#                                 Trades & Services                         0.181818
#                                 Farming, Animals & Conservation           0.090909
#                                 Mining, Resources & Energy                0.090909
# ...

# %%
byLocation.index
# Out:
# MultiIndex([(                           'ACT', ...),
#             (                           'ACT', ...),
#             (                           'ACT', ...),
#             (                           'ACT', ...),
#             (                           'ACT', ...),
#             (                           'ACT', ...),
#             (                           'ACT', ...),
#             (                           'ACT', ...),
#             (                           'ACT', ...),
#             (                           'ACT', ...),
#             ...
#             (   'Yarra Valley & High Country', ...),
#             (   'Yarra Valley & High Country', ...),
#             (   'Yarra Valley & High Country', ...),
#             (   'Yarra Valley & High Country', ...),
#             (   'Yarra Valley & High Country', ...),
#             ('Yorke Peninsula & Clare Valley', ...),
#             ('Yorke Peninsula & Clare Valley', ...),
# ...

# %%
byLocation.unstack()
# Out:
# Classification                       Accounting  \
# Location
# ACT                                    0.016807
# Adelaide                               0.030769
# Adelaide Hills & Barossa                    NaN
# Albany & Great Southern                     NaN
# Albury Area                                 NaN
# ...                                         ...
# Western QLD                                 NaN
# Whyalla & Eyre Peninsula                    NaN
# Wollongong, Illawarra & South Coast    0.034483
# Yarra Valley & High Country                 NaN
# Yorke Peninsula & Clare Valley              NaN
#
# Classification                       Administration & Office Support  \
# Location
# ACT                                                         0.100840
# Adelaide                                                    0.092308
# Adelaide Hills & Barossa                                    0.052632
# Albany & Great Southern                                          NaN
# ...

# %%
byClassification = df.groupby("Classification").Location.value_counts(normalize=True)
byClassification
# Out:
# Classification     Location
# Accounting         Sydney                       0.362434
#                    Melbourne                    0.259259
#                    Brisbane                     0.116402
#                    Perth                        0.082011
#                    Adelaide                     0.031746
#                                                   ...
# Trades & Services  Northam & Wheatbelt          0.000816
#                    Riverland & Murray Mallee    0.000816
#                    Somerset & Lockyer           0.000816
#                    Tamworth & North West NSW    0.000816
#                    Whyalla & Eyre Peninsula     0.000816
# Name: Location, Length: 832, dtype: float64

# %%
byClassification.plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Classification,Location'>

# %%
byLocation.plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Location,Classification'>

# %%
df.Classification.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
byLocation.plot(kind='barh',figsize=(8,8))
# Out:
# <AxesSubplot:ylabel='Location,Classification'>

# %%
Location_of_Jobs =df['Location'].value_counts()
Location_of_Jobs
# Out:
# Sydney                                  2784
# Melbourne                               2481
# Brisbane                                1119
# Perth                                    677
# Adelaide                                 390
#                                         ...
# Fleurieu Peninsula & Kangaroo Island       6
# Tumut, Snowy & Monaro                      4
# Somerset & Lockyer                         4
# Central & South East TAS                   3
# Coober Pedy & Outback SA                   1
# Name: Location, Length: 65, dtype: int64

# %%
Type_of_Job =df['Classification'].value_counts()
Type_of_Job
# Out:
# Hospitality & Tourism                     1585
# Trades & Services                         1225
# Manufacturing, Transport & Logistics       990
# Retail & Consumer Products                 896
# Administration & Office Support            746
# Healthcare & Medical                       622
# Information & Communication Technology     411
# Education & Training                       401
# Sales                                      389
# Accounting                                 378
# Call Centre & Customer Service             342
# Construction                               265
# Community Services & Development           258
# Real Estate & Property                     228
# Government & Defence                       203
# Mining, Resources & Energy                 176
# Banking & Financial Services               153
# Marketing & Communications                 139
# Human Resources & Recruitment              138
# Engineering                                126
# ...

# %%
# %matplotlib inline
Type_of_Job.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline

plt.bar("Classification", "Location")
plt.xlabel("No. Jobs in Location")
plt.ylabel("Classification")
plt.title("Job by Location")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ax = sns.scatterplot(x="Location", y="Classification", 
    hue="Location",data=df)

# %%
sns.catplot(x="Classification", y="Location", 
            hue="day", data=df, kind="box")

plt.xticks(range(len(bars_label)), bars_label, rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/h0/8_wby_212cs0h3_gmjklt61c0000gn/T/ipykernel_8401/2173531314.py in <module>
# ----> 1 sns.catplot(x="Classification", y="Location",
#       2             hue="day", data=df, kind="box")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790     p = _CategoricalPlotter()
# ...

# %%
import matplotlib.pyplot as plt

data_x = df("Location")
data_y = df("Classification")

plt.xlabel("CITY")
plt.ylabel("POPULATION")
plt.title("BAR PLOT")
plt.barh(data_x, data_y, color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/h0/8_wby_212cs0h3_gmjklt61c0000gn/T/ipykernel_8401/2777739058.py in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 data_x = df("Location")
#       4 data_y = df("Classification")
#       5
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# ## job posts by salary range

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['SalaryRange'] =pd.cut(df.)

# %%
y = df.["HighestSalary"]

plt.pie(y)
plt.show()
# Out:
#   File "/var/folders/h0/8_wby_212cs0h3_gmjklt61c0000gn/T/ipykernel_8401/2379870791.py", line 1
#     y = df.["HighestSalary"]
#            ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['Civil', 'Electrical', 'Mechanical', 'Chemical']
sizes = [15, 50, 45, 10]


fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
ax.set_title('Engineering Diciplines')


plt.show()

# %% [markdown]
# ## 2. Data Correlation

# %%
wd = pd.read_csv("wine.data.csv")

# %%
wd.head()
# Out:
#    Label  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280  Proline
# 0             5.64  1.04   3.92     1065
# 1             4.38  1.05   3.40     1050
# ...

# %%
wd.drop(['Label'], axis=1)
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
x_axis = wd['Alcohol']
y_axis = wd['Color intensity']

plt.title('Relationship between Alcohol and Color Intensity in Wine')
plt.xlabel('Alcohol')
plt.ylabel('Color Intensity')

plt.scatter(x_axis, y_axis, color = 'b', marker ='*', s=20)
plt.show()

# %% [markdown]
# #Analysis: the greater the amount of alcohol in wine, the greater the colour intensity is.

# %%
## questions. for part 2. Do we just do one scatter chart, or are we supposed to make a chart as 
#demonstrated in the Assigned exercises?

# %%
wd.corr()
# Out:
#                          Label   Alcohol  Malic acid       Ash  \
# Label                 1.000000 -0.328222    0.437776 -0.049643
# Alcohol              -0.328222  1.000000    0.094397  0.211545
# Malic acid            0.437776  0.094397    1.000000  0.164045
# Ash                  -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash     0.517859 -0.310235    0.288500  0.443367
# Magnesium            -0.209179  0.270798   -0.054575  0.286587
# Total phenols        -0.719163  0.289101   -0.335167  0.128980
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols  0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins      -0.499130  0.136698   -0.220746  0.009652
# Color intensity       0.265668  0.546364    0.248985  0.258887
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667
# OD280                -0.788230  0.072343   -0.368710  0.003911
# Proline              -0.633717  0.643720   -0.192011  0.223626
#
# ...

# %%
sns.heatmap(wd.corr(),cmap='coolwarm',annot=True,)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysis:
# List three pairs of attributes which have the largest correlation?
#
# Blue- less correlation
# Red - greatest correlation
#
# So the pairs with the most correlation are 'total phenols-Flavanoids' (with 0.86), 'Flavanoids-OD280' (with0.79)
# and 'total phenols' (with 0.70).

# %%
# questions, is there a way to make the values in the box's smaller, or the map larger? Just to make it more legible.

# %% [markdown]
# ## K-Means

# %%
kMeansClustering = KMeans(n_clusters = 3, random_state=0)
res = kMeansClustering.fit_predict(wine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/h0/8_wby_212cs0h3_gmjklt61c0000gn/T/ipykernel_8401/1842396870.py in <module>
# ----> 1 kMeansClustering = KMeans(n_clusters = 3, random_state=0)
#       2 res = kMeansClustering.fit_predict(wine)
#
# NameError: name 'KMeans' is not defined

# %%
wd.head()
# Out:
#    Label  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280  Proline
# 0             5.64  1.04   3.92     1065
# 1             4.38  1.05   3.40     1050
# ...

# %%
wd.columns
# Out:
# Index(['Label', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'OD280', 'Proline'],
#       dtype='object')

# %%
y = wd.columns[1:14]
y
# Out:
# Index(['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium',
#        'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'OD280', 'Proline'],
#       dtype='object')

# %%
# I did [1-14] instead of [0-14], becuase if you enter 0-14, it adds the labels column, 
#which I didn't want. Proceeded the same for x values.

# %%
x = wd.iloc[:, 1:14]
x.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# ...

# %%
x[y=='Alcohol'].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/h0/8_wby_212cs0h3_gmjklt61c0000gn/T/ipykernel_8401/2322157219.py in <module>
# ----> 1 x[y=='Alcohol'].head()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3494         # Do we have a (boolean) 1d indexer?
#    3495         if com.is_bool_indexer(key):
# -> 3496             return self._getitem_bool_array(key)
#    3497
#    3498         # We are left with two options: a single key, and a collection of keys,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3541             )
#    3542         elif len(key) != len(self.index):
# -> 3543             raise ValueError(
#    3544                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    3545             )
#
# ...

# %%
## question: If we're not able to figure out the code and answer the question, will the tutor-- or whoever is marking
## explain where we went wrong? or...
